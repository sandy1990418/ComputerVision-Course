# %%
## read opencv package
import cv2
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import os
from skimage import data
import numpy as np 
####################################################################

## read image
image = data.camera() 
dimension = image .shape
plt.imshow(image, cmap='gray')
print("Height，Width，Channel:",dimension)
# Out:
# Height，Width，Channel: (512, 512)

# %%
image
# Out:
# array([[200, 200, 200, ..., 189, 190, 190],
#        [200, 199, 199, ..., 190, 190, 190],
#        [199, 199, 199, ..., 190, 190, 190],
#        ...,
#        [ 25,  25,  27, ..., 139, 122, 147],
#        [ 25,  25,  26, ..., 158, 141, 168],
#        [ 25,  25,  27, ..., 151, 152, 149]], dtype=uint8)

# %%
kernal = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])

# %%
test_image = image


kernal = np.array([[-2,-1,0],[-1,1,1],[0,1,2]])

# %%
kernal = np.array([[0,0,0],[0,1,0],[0,0,0]])

# %%
convolution = np.array([[test_image[0][j-1],test_image[0][j],test_image[0][j+1]],
                        [test_image[1][j-1],test_image[1][j],test_image[1][j+1]],
                        [test_image[i+1][j-1],test_image[i+1][j],test_image[i+1][j+1]]])

# %%
image
# Out:
# array([[200, 200, 200, ..., 189, 190, 190],
#        [200, 199, 199, ..., 190, 190, 190],
#        [199, 199, 199, ..., 190, 190, 190],
#        ...,
#        [ 25,  25,  27, ..., 139, 122, 147],
#        [ 25,  25,  26, ..., 158, 141, 168],
#        [ 25,  25,  27, ..., 151, 152, 149]], dtype=uint8)

# %%
for i in range(dimension[0]):
    for j in range(dimension[1]):
        if np.any(np.array([i-1,j-1])<0)==True:
            test_image[i][j]=0
        elif np.any(np.array([i+1,j+1])>511)==True:
            test_image[i][j]=0
        else:
            convolution = np.array([[test_image[i-1][j-1],test_image[i-1][j],test_image[i-1][j+1]],
                                    [test_image[i][j-1],test_image[i][j],test_image[i][j+1]],
                                    [test_image[i+1][j-1],test_image[i+1][j],test_image[i+1][j+1]]])
            test_image[i][j]=np.sum((convolution*kernal))
            #print(test_image[i][j])

# %%
test_image
# Out:
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [  0, 227,   3, ..., 192, 246,   0],
#        [  0,   1,  26, ...,  53,  11,   0],
#        ...,
#        [  0,  71, 103, ..., 191,  38,   0],
#        [  0,  59,  79, ..., 113, 226,   0],
#        [  0,   0,   0, ...,   0,   0,   0]], dtype=uint8)

# %%
plt.imshow(test_image, cmap='gray')

# %%
matrix= []
for i in range(int(-1*(3-1)/2),int((3-1)/2+1)):
    matrix.append(i)
row = np.array( np.matrix(matrix).T * np.matrix([1]*3))
column = row.T

# %%
(row.T)
# Out:
# array([[-1,  0,  1],
#        [-1,  0,  1],
#        [-1,  0,  1]])

# %%
(row+1)[0]
# Out:
# array([0, 0, 0])

# %%
image[(row+1)[0][1]][(row.T+1)[0][0:4]]
# Out:
# array([200, 200, 200], dtype=uint8)

# %%
for i in range(1):
    test = row+i

# %%
np.all(test[[2]]<0)==True
# Out:
# False

# %%
row = np.array( np.matrix(matrix).T * np.matrix([1]*5))

# %%
for i in range(5):
    for j in range(5):
        convolution = []
        for k in range(int(-1*(5-1)/2),int((5-1)/2+1)):
            row = []
            for w in range(int(-1*(5-1)/2),int((5-1)/2+1)):
                row.append(w)

        
            print(row)

# %%
convolution = []
for i in range(int(-1*(5-1)/2),int((5-1)/2+1)):
    row = []
    for j in range(int(-1*(5-1)/2),int((5-1)/2+1)):
        row.append(j)

 
    print(row)
# Out:
# [-2, -1, 0, 1, 2]
# [-2, -1, 0, 1, 2]
# [-2, -1, 0, 1, 2]
# [-2, -1, 0, 1, 2]
# [-2, -1, 0, 1, 2]

# %%
plus_and_minus=np.array([-1,0,+1])

# %%
(plus_and_minus*2)[0]
# Out:
# 2
